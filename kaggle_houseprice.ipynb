# %% [markdown]
# METHOD 1 : DROPING COLUMNS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# load data set

# %%
original_dataset=pd.read_csv("D:\\my work\\ml\\kaggle_hp.csv")

# %%
original_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# display all rows and columns

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
original_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# take information

# %%
original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
original_dataset.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# visualize null values

# %%
plt.figure(figsize=(25,25))
sns.heatmap(original_dataset.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# to remove this white space we first have to find percentage of null values in each column

# %%
null_values_percentage=original_dataset.isnull().sum()/original_dataset.shape[0]*100
null_values_percentage
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %% [markdown]
# drop coulmns whose null value > 17 %

# %%
columns_with_moreThan17Percentage=null_values_percentage[null_values_percentage>17].keys()
columns_with_moreThan17Percentage
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
# drop null value columns from original dataset
dropped_columns=original_dataset.drop(columns=columns_with_moreThan17Percentage)

# %%
dropped_columns.shape
# Out:
# (1460, 75)

# %% [markdown]
# check how much data is cleaned after droping null value columns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(dropped_columns.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# METHOD 2 : DROPING ROWS

# %%
 #drop function by default drop null rows and we r droping rows from df2_drop_column(data after droping null value columns i.e droping rows from clean column data)
dropped_row=dropped_columns.dropna()

# %%
dropped_row.shape
# Out:
# (1338, 75)

# %% [markdown]
# look how our data set looks like after deleting row

# %%
plt.figure(figsize=(15,15))
sns.heatmap(dropped_row.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# still how much null values present in rows and columns

# %%
print(dropped_columns.isnull().sum().sum())
print(dropped_row.isnull().sum().sum())
# Out:
# 609
# 0

# %% [markdown]
# accuracy

# %%
dropped_row.select_dtypes(include=['int','float']).columns
# now i want to plot displot of how our clean dataset looks like we first select columns having data type i.e int and float
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# visualizing diffrence in original data set and new dataset df3_drop_row after droping null rows

# %%
sns.distplot(original_dataset['MSSubClass'])
sns.distplot(dropped_row['MSSubClass'])
# Out:
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSSubClass', ylabel='Density'>

# %%
numerical_var=['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
       'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'MoSold', 'YrSold', 'SalePrice']

# %% [markdown]
# overlapping original data set with df3_drop_row (columns) having numerical value

# %%
plt.figure(figsize=(25,25))
for i,var in enumerate(numerical_var):
    plt.subplot(6,6,i+1)
    sns.distplot(original_dataset[var])
    sns.distplot(dropped_row[var])
# Out:
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
#  now i want to accuracy of how our clean dataset looks like we first select columns having data type i.e object-categorical datatyppe and then compare with original dataset

# %%
dropped_row.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
categorical_variable=['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']

# %%
# example
# we concate two columns[1 COLUMN=value count of categorical data of any variable in percentage from original dataset,2 COLUMN=value count of categorical data of any variable in percentage from clean dataset]
pd.concat([original_dataset['MSZoning'].value_counts()/original_dataset.shape[0] * 100,dropped_row['MSZoning'].value_counts()/dropped_row.shape[0] * 100],axis=1,keys=['original','clean'])
# Out:
#           original      clean
# RL       78.835616  79.671151
# RM       14.931507  14.275037
# FV        4.452055   4.633782
# RH        1.095890   0.822123
# C (all)   0.684932   0.597907

# %% [markdown]
# from these distribution columns percentage we can see how minor changes are there in our oroginal data set and new data set
# and this leads us to accuracy

# %%
# using function
def cat_var_distribution(var):

    return pd.concat([original_dataset[var].value_counts()/original_dataset.shape[0] * 100,dropped_row[var].value_counts()
    /dropped_row.shape[0] * 100],axis=1,keys=[var+'_original',var+'_clean'])

cat_var_distribution('CentralAir')
# Out:
#    CentralAir_original  CentralAir_clean
# Y            93.493151         95.440957
# N             6.506849          4.559043

# %%
# using for loop

for i,var in enumerate(categorical_variable):
    print(pd.concat([original_dataset[var].value_counts()/original_dataset.shape[0] * 100,dropped_row[var].value_counts()
    /dropped_row.shape[0] * 100],axis=1,keys=[var+'_original',var+'_clean']))
    print("\n")
# Out:
#          MSZoning_original  MSZoning_clean
# RL               78.835616       79.671151
# RM               14.931507       14.275037
# FV                4.452055        4.633782
# RH                1.095890        0.822123
# C (all)           0.684932        0.597907
#
#
#       Street_original  Street_clean
# Pave        99.589041     99.626308
# Grvl         0.410959      0.373692
#
#
#      LotShape_original  LotShape_clean
# Reg          63.356164       61.958146
# IR1          33.150685       34.304933
# IR2           2.808219        2.989537
# IR3           0.684932        0.747384
#
#
#      LandContour_original  LandContour_clean
# Lvl             89.794521          90.134529
# Bnk              4.315068           3.886398
# HLS              3.424658           3.587444
# Low              2.465753           2.391629
#
#
#         Utilities_original  Utilities_clean
# AllPub           99.931507        99.925262
# NoSeWa            0.068493         0.074738
#
#
# ...

# %% [markdown]
# MISSING VALUE IMPUTATION BY MEAN,MEDIAN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load original data set

# %%
numerical_data=original_dataset.select_dtypes(include=['int','float'])
numerical_data.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# original dataset information

# %%
numerical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   BsmtFinSF1     1460 non-null   int64
#  10  BsmtFinSF2     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  1stFlrSF       1460 non-null   int64
#  14  2ndFlrSF       1460 non-null   int64
#  15  LowQualFinSF   1460 non-null   int64
#  16  GrLivArea      1460 non-null   int64
#  17  BsmtFullBath   1460 non-null   int64
# ...

# %% [markdown]
# missing values in percentage in numerical data

# %%
numerical_data.isnull().sum()/numerical_data.shape[0] *100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# MasVnrArea        0.547945
# BsmtFinSF1        0.000000
# BsmtFinSF2        0.000000
# BsmtUnfSF         0.000000
# TotalBsmtSF       0.000000
# 1stFlrSF          0.000000
# 2ndFlrSF          0.000000
# LowQualFinSF      0.000000
# GrLivArea         0.000000
# BsmtFullBath      0.000000
# BsmtHalfBath      0.000000
# FullBath          0.000000
# HalfBath          0.000000
# BedroomAbvGr      0.000000
# KitchenAbvGr      0.000000
# TotRmsAbvGrd      0.000000
# Fireplaces        0.000000
# GarageYrBlt       5.547945
# GarageCars        0.000000
# GarageArea        0.000000
# WoodDeckSF        0.000000
# OpenPorchSF       0.000000
# EnclosedPorch     0.000000
# 3SsnPorch         0.000000
# ScreenPorch       0.000000
# PoolArea          0.000000
# ...

# %% [markdown]
# heatmap for missing data from numerical data

# %%
plt.figure(figsize=(10,10))
sns.heatmap(numerical_data)
# Out:
# <AxesSubplot:>

# %%
numerical_data[numerical_data.isnull().any(axis=1)].head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 7    8          60          NaN    10382            7            6       1973
# 12  13          20          NaN    12968            5            6       1962
# 14  15          20          NaN    10920            6            5       1960
# 16  17          20          NaN    11241            6            7       1970
# 24  25          20          NaN     8246            5            8       1968
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 7           1973       240.0         859          32        216         1107
# 12          1962         0.0         737           0        175          912
# 14          1960       212.0         733           0        520         1253
# 16          1970       180.0         578           0        426         1004
# 24          2001         0.0         188         668        204         1060
#
# ...

# %% [markdown]
# column names with null values in numerical data

# %%
missing_numerical_data=[var for var in numerical_data if numerical_data[var].isnull().sum()>0]
missing_numerical_data
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# displot for missing numerical data

# %%
plt.figure(figsize=(20,10))
for i,var in enumerate(missing_numerical_data):
    plt.subplot(1,3,i+1)
    sns.distplot(numerical_data[var],color="red",bins=20)
# Out:
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# filling null values with mean and ploting its displot for original dataset vs filled mean value dataset

# %%
filled_value_mean=numerical_data.fillna(numerical_data.mean())
filled_value_mean.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(25,25))
for i,var in enumerate(missing_numerical_data):
    plt.subplot(2,2,i+1)
    sns.distplot(df[var],label="original",kde_kws={'linewidth':7})
    sns.distplot(filled_value_mean[var],label="filled value",kde_kws={'linewidth':7})
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DISHAD~1\AppData\Local\Temp/ipykernel_6540/376596178.py in <module>
#       2 for i,var in enumerate(missing_numerical_data):
#       3     plt.subplot(2,2,i+1)
# ----> 4     sns.distplot(df[var],label="original",kde_kws={'linewidth':7})
#       5     sns.distplot(filled_value_mean[var],label="filled value",kde_kws={'linewidth':7})
#       6     plt.legend()
#
# NameError: name 'df' is not defined

# %% [markdown]
# filling null values with median nd plotting displot for original data set and mean filled data set

# %%
filled_value_median=numerical_data.fillna(numerical_data.median())
filled_value_median.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(25,25))
for i,var in enumerate(missing_numerical_data):
    plt.subplot(2,2,i+1)
    sns.distplot(df[var],label="original",hist=False,kde_kws={'linewidth':7})
    sns.distplot(filled_value_median[var],hist=False,label="filled value",kde_kws={'linewidth':7})
    
    plt.legend()
# Out:
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# plotiing displot for all data sets i.e original data set,mean filled data set and median filled data set

# %%
plt.figure(figsize=(25,25))
for i,var in enumerate(missing_numerical_data):
    plt.subplot(2,2,i+1)
    sns.distplot(df[var],label="original",hist=False,kde_kws={'linewidth':7})
    sns.distplot(filled_value_median[var],hist=False,label="filled value",kde_kws={'linewidth':7})
    sns.distplot(filled_value_mean[var],hist=False,label="filled value",kde_kws={'linewidth':7})
    plt.legend()
# Out:
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DishaDevani\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# NUMERICAL VALUE IMPUTATION BY CLASS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
original_dataset.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_columns',None)

# %%
original_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
null_columns=original_dataset.isnull().sum()/original_dataset.shape[0] *100
null_columns
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
columns_with_MoreThan17Percentage=null_values_percentage[null_values_percentage>17].keys()

# %%
drop_colum=original_dataset.drop(columns=columns_with_MoreThan17Percentage)
drop_colum.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
# ...

# %%
numerical_data.shape
# Out:
# (1460, 38)

# %%
numerical_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
concate=pd.concat([original_dataset['LotFrontage'],original_dataset['MasVnrArea'],original_dataset['GarageYrBlt']],keys=['LotFrontage','MasVnrArea','GarageYrBlt'],axis=1)
concate.head()
# Out:
#    LotFrontage  MasVnrArea  GarageYrBlt
# 0         65.0       196.0       2003.0
# 1         80.0         0.0       1976.0
# 2         68.0       162.0       2001.0
# 3         60.0         0.0       1998.0
# 4         84.0       350.0       2000.0

# %%
original_dataset['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %% [markdown]
# VALUE IMPUTATION BY PLACING MEAN OR MEDIAN VALUES CALCULATED GROUPBY
